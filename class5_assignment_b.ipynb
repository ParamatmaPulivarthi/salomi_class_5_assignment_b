# %%
task_2:

# %%
younge_age 10---20
teen_age >20----40

# %%
my_age=20

# %%
comparision_value=20

# %%
print("your program start")
if my_age >=comparision_value:
    print("you are teen_age")
else:
    print("you are younge_age")
print("your program ends")
# Out:
# your program start
# you are teen_age
# your program ends

# %%
my_age=30

# %%
comparision_value=20

# %%
print("your program start")
if my_age >=comparision_value :
    print("you are younge_age")
else:
    print("you are teen_age")
print("your program ends")
# Out:
# your program start
# you are younge_age
# your program ends

# %%
my_age=10

# %%
comparision_value=20

# %%
print("your program start")
if my_age < comparision_value:
    print("you are younge_age")
else:
    print("you are teen_age")
print("your program ends")
# Out:
# your program start
# you are younge_age
# your program ends

# %%
my_age=40

# %%
comparision_value=20

# %%
print("your program start")
if my_age >= comparision_value:
    print("you are teen_age")
else:
    print("you are younge_age")
print("your program ends")
# Out:
# your program start
# you are teen_age
# your program ends

# %%
weekday=["monday","tuesday","wednesday","thursday","friday"]

# %%
weekend=["saturday","sunday"]

# %%
print("your program start")
if weekday:
    print("today is a weekday:",weekday)
else:
    print("today is weekend")
print("your program ends")
# Out:
# your program start
# today is a weekday: ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
# your program ends

# %%
print("your program start")
if weekend:
    print("today is a weekend:",weekend)
else:
    print("today is weekday")
print("your program ends")
# Out:
# your program start
# today is a weekend: ['saturday', 'sunday']
# your program ends

# %%
day="weekend"#weekday/weekend

# %%
weekday=["monday","tuesday","wednesday","thursday","friday"]

# %%
weekend=["saturday","sunday"]

# %%
print("your program start")
if day=="weekday":
    print("today is weekday",weekday)
elif day=="weekend":
    print("today is weekend",weekend)
print("your program ends")
# Out:
# your program start
# today is weekday ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
# your program ends

# %%
print("your program start")
if day=="weekday":
    print("today is weekday",weekday)
elif day=="weekend":
    print("today is weekend",weekend)
print("your program ends")
# Out:
# your program start
# today is weekend ['saturday', 'sunday']
# your program ends

# %%
Task_3:

# %%
scenario1:today my business income 10 morethan print profit
   otherwise print loss

# %%
original_value=10

# %%
comparision_value=10

# %%
if original_value>=comparision_value:
    print("your business is profit")
    print("congrats")
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is profit
# congrats

# %%
if original_value>=comparision_value:
    print("your business is profit")
    print("congrats")
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is loss
# better luck next day

# %%
if original_value>=comparision_value:
    print("your business is profit")
    
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is profit

# %%
scenario2:
# define the ages

# %%
your_age=28

# %%
sister_age=29

# %%
if your_age>sister_age:
    print("i am elder")
else:
    print("i am younger")
# Out:
# i am elder

# %%
if your_age<sister_age:
    print("i am elder")
else:
    print("i am younger")
# Out:
# i am younger

# %%
if your_age>=sister_age:
    print("i am elder")
else:
    print("i am younger")
# Out:
# i am elder

# %%
if your_age>=sister_age:
    print("i am elder")
else:
    print("i am younger")
# Out:
# i am younger

# %%
#scenario3:festival offer in my shop

# %%
purchase_amount=100

# %%
if purchase_amount >=100:
    print(" you got 30% discount")
elif purchase_amount >=50:
    print("you got 10% discount")
else:
    print("you got 20% discount")
# Out:
#  you got 30% discount

# %%
if purchase_amount >100:
    print(" you got 30% discount")
elif purchase_amount <50:
    print("you got 10% discount")
else:
    print("you got 20% discount")
# Out:
# you got 20% discount

# %%
if purchase_amount >100:
    print(" you got 30% discount")
elif purchase_amount >=50:
    print("you got 10% discount")
else:
    print("you got 20% discount")
# Out:
# you got 10% discount

# %%
# scenario4:movie theater prices

# %%
price=140 #140/50/100
seat_type="balcony"#balcony/chair/bench

# %%
if price==140:
    print(" your selected seat type is:",seat_type)
    print("your seat type movie price is:", price)
elif price==50:
    print("your selected seat type is:", seat_type)
    print("your seat type movie price is:",price)
elif price==100:
    print("your selected seat type is:",seat_type )
    print("your seat type movie price is:", price)
# Out:
#  your selected seat type is: balcony
# your seat type movie price is: 140

# %%
price=50 #140/50/100
seat_type="chair"#balcony/chair/bench

# %%
if price==140:
    print(" your selected seat type is:",seat_type)
    print("your seat type movie price is:", price)
elif price==50:
    print("your selected seat type is:", seat_type)
    print("your seat type movie price is:",price)
elif price==100:
    print("your selected seat type is:",seat_type )
    print("your seat type movie price is:", price)
# Out:
# your selected seat type is: chair
# your seat type movie price is: 50

# %%
price=100 #140/50/100
seat_type="bench"#balcony/chair/bench

# %%
if price==140:
    print(" your selected seat type is:",seat_type)
    print("your seat type movie price is:", price)
elif price==50:
    print("your selected seat type is:", seat_type)
    print("your seat type movie price is:",price)
elif price==100:
    print("your selected seat type is:",seat_type )
    print("your seat type movie price is:", price)
# Out:
# your selected seat type is: bench
# your seat type movie price is: 100

# %%
#scenario5: vehicle showroom classifier

# %%
# input variables:my showroom vehicle types details
vehicle_type="two wheeler"#two wheeler/four wheeler
type_vehicle_name="bike,scooty"#bike,scooty/car,loory,van,zeep

# %%
if vehicle_type =="two wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)

elif vehicle_type =="four wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)
else:
    print("the specific vehicle is not available")
# Out:
# your vehicle type is: two wheeler
# available vehicle name is: bike,scooty

# %%
# input variables:my showroom vehicle types details
vehicle_type="four wheeler"#two wheeler/four wheeler
type_vehicle_name="car,loory,van,zeep"#bike,scooty/car,loory,van,zeep

# %%
if vehicle_type =="two wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)

elif vehicle_type =="four wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)
else:
    print("the specific vehicle is not available")
# Out:
# your vehicle type is: two wheeler
# available vehicle name is: bike,scooty

# %%
# input variables:my showroom vehicle types details
vehicle_type="three wheeler"#two wheeler/four wheeler
type_vehicle_name="auto"#bike,scooty/car,loory,van,zeep

# %%
if vehicle_type =="two wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)

elif vehicle_type =="four wheeler":
    print("your vehicle type is:",vehicle_type)
    print("available vehicle name is:",type_vehicle_name)
else:
    print("the specific vehicle is not available")
# Out:
# the specific vehicle is not available
